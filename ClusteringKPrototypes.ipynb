# %% [markdown]
# # K-Prototypes Clustering: Mencari K Terbaik (Elbow & Silhouette)
# Notebook ini berisi perbaikan alur preprocessing dan loop otomatis untuk menentukan jumlah cluster (K) yang paling optimal.

# %%
import pandas as pd
import numpy as np
from kmodes.kprototypes import KPrototypes
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %%
df = pd.read_csv('DataCleanLabel.csv')

# %%
df['BMI'] = df['Weight'] / (df['Height'] ** 2)

features_selected = [
    'BMI', 'FAF', 'FCVC', # Numerik
    'family_history_with_overweight', 'CAEC' , 'FAVC' # Kategorik
]
data_kproto = df[features_selected].copy()

# %%
scaler = MinMaxScaler()
num_cols = ['BMI', 'FAF', 'FCVC'] 
data_kproto[num_cols] = scaler.fit_transform(data_kproto[num_cols])

cat_cols_index = [3, 4,5] # Index kolom kategorikal (0=BMI, 1=FAF, 2=FCVC, 3=History...)
data_matrix = data_kproto.values

# %%
kproto = KPrototypes(n_clusters=4, init='Cao', verbose=1)
clusters = kproto.fit_predict(data_matrix, categorical=cat_cols_index)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 514, ncost: 334.0976654587752
# Run: 1, iteration: 2/100, moves: 326, ncost: 297.5204009836637
# Run: 1, iteration: 3/100, moves: 298, ncost: 284.9534936673045
# Run: 1, iteration: 4/100, moves: 133, ncost: 277.8353172214227
# Run: 1, iteration: 5/100, moves: 74, ncost: 275.62465030886557
# Run: 1, iteration: 6/100, moves: 47, ncost: 274.3118462225146
# Run: 1, iteration: 7/100, moves: 42, ncost: 273.1848106849919
# Run: 1, iteration: 8/100, moves: 10, ncost: 273.16357400578704
# Run: 1, iteration: 9/100, moves: 0, ncost: 273.16357400578704
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 848, ncost: 307.4288048847685
# Run: 2, iteration: 2/100, moves: 288, ncost: 291.178181512879
# Run: 2, iteration: 3/100, moves: 291, ncost: 273.71818754973236
# Run: 2, iteration: 4/100, moves: 105, ncost: 271.1185720053062
# Run: 2, iteration: 5/100, moves: 39, ncost: 270.46644874925624
# Run: 2, iteration: 6/100, moves: 34, ncost: 270.02085331420477
# Run: 2, iteration: 7/100, moves: 32, ncost: 269.5794652615377
# Run: 2, iteration: 8/100, moves: 26, ncost: 269.3127899441921
# Run: 2, iteration: 9/100, moves: 9, ncost: 269.28264039711513
# Run: 2, iteration: 10/100, moves: 0, ncost: 269.28264039711513
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 563, ncost: 276.6429907467348
# Run: 3, iteration: 2/100, moves: 127, ncost: 273.33864474621475
# Run: 3, iteration: 3/100, moves: 27, ncost: 273.17784425957717
# Run: 3, iteration: 4/100, moves: 7, ncost: 273.16357400578676
# Run: 3, iteration: 5/100, moves: 0, ncost: 273.16357400578676
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 546, ncost: 304.96086070021767
# Run: 4, iteration: 2/100, moves: 410, ncost: 283.8584047761998
# Run: 4, iteration: 3/100, moves: 128, ncost: 281.6912914428967
# Run: 4, iteration: 4/100, moves: 29, ncost: 281.5456486931437
# Run: 4, iteration: 5/100, moves: 5, ncost: 281.52436568571056
# Run: 4, iteration: 6/100, moves: 0, ncost: 281.52436568571056
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 555, ncost: 281.81530380923493
# Run: 5, iteration: 2/100, moves: 180, ncost: 272.8864454347997
# Run: 5, iteration: 3/100, moves: 126, ncost: 269.64809455742187
# Run: 5, iteration: 4/100, moves: 36, ncost: 269.3212500754736
# Run: 5, iteration: 5/100, moves: 13, ncost: 269.2835568598592
# Run: 5, iteration: 6/100, moves: 1, ncost: 269.28277176907164
# Run: 5, iteration: 7/100, moves: 0, ncost: 269.28277176907164
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 569, ncost: 357.3110028891492
# Run: 6, iteration: 2/100, moves: 348, ncost: 306.2146377345249
# Run: 6, iteration: 3/100, moves: 273, ncost: 285.79770564374303
# Run: 6, iteration: 4/100, moves: 146, ncost: 280.5381882810441
# Run: 6, iteration: 5/100, moves: 41, ncost: 280.1957481791821
# Run: 6, iteration: 6/100, moves: 20, ncost: 280.0272427828368
# Run: 6, iteration: 7/100, moves: 15, ncost: 279.8334865266804
# Run: 6, iteration: 8/100, moves: 26, ncost: 279.37956032539097
# Run: 6, iteration: 9/100, moves: 43, ncost: 278.5603526034106
# Run: 6, iteration: 10/100, moves: 13, ncost: 278.49208996146297
# Run: 6, iteration: 11/100, moves: 0, ncost: 278.49208996146297
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 828, ncost: 279.8858241386632
# Run: 7, iteration: 2/100, moves: 257, ncost: 270.3898198427625
# Run: 7, iteration: 3/100, moves: 50, ncost: 269.9078523141945
# Run: 7, iteration: 4/100, moves: 39, ncost: 269.416576828298
# Run: 7, iteration: 5/100, moves: 16, ncost: 269.3096501486008
# Run: 7, iteration: 6/100, moves: 7, ncost: 269.2826403971155
# Run: 7, iteration: 7/100, moves: 0, ncost: 269.2826403971155
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 574, ncost: 287.04363366927134
# Run: 8, iteration: 2/100, moves: 89, ncost: 285.8561270277355
# Run: 8, iteration: 3/100, moves: 38, ncost: 285.5441465933847
# Run: 8, iteration: 4/100, moves: 38, ncost: 285.19258898627896
# Run: 8, iteration: 5/100, moves: 3, ncost: 285.1893106919321
# Run: 8, iteration: 6/100, moves: 1, ncost: 285.185418025631
# Run: 8, iteration: 7/100, moves: 7, ncost: 285.15826558618414
# Run: 8, iteration: 8/100, moves: 5, ncost: 285.1446986708154
# Run: 8, iteration: 9/100, moves: 4, ncost: 285.1383706586871
# Run: 8, iteration: 10/100, moves: 5, ncost: 285.13039258511054
# Run: 8, iteration: 11/100, moves: 3, ncost: 285.1276777757338
# Run: 8, iteration: 12/100, moves: 3, ncost: 285.1263961429264
# Run: 8, iteration: 13/100, moves: 0, ncost: 285.1263961429264
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 487, ncost: 296.86330934809166
# Run: 9, iteration: 2/100, moves: 105, ncost: 295.6561370952454
# Run: 9, iteration: 3/100, moves: 77, ncost: 293.7656748838935
# Run: 9, iteration: 4/100, moves: 52, ncost: 292.7157438145924
# Run: 9, iteration: 5/100, moves: 45, ncost: 292.06533278893994
# Run: 9, iteration: 6/100, moves: 11, ncost: 292.03410423447116
# Run: 9, iteration: 7/100, moves: 3, ncost: 292.03178788521376
# Run: 9, iteration: 8/100, moves: 1, ncost: 292.0313882706168
# Run: 9, iteration: 9/100, moves: 0, ncost: 292.0313882706168
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 648, ncost: 285.8360737639502
# Run: 10, iteration: 2/100, moves: 98, ncost: 285.1883542905453
# Run: 10, iteration: 3/100, moves: 17, ncost: 285.1369908469837
# Run: 10, iteration: 4/100, moves: 4, ncost: 285.13327339558754
# Run: 10, iteration: 5/100, moves: 1, ncost: 285.13217426187856
# Run: 10, iteration: 6/100, moves: 2, ncost: 285.1293783680049
# Run: 10, iteration: 7/100, moves: 4, ncost: 285.1267631473935
# Run: 10, iteration: 8/100, moves: 0, ncost: 285.1267631473935
# Best run was number 2

# %%
df_eval = pd.get_dummies(data_kproto, columns=['family_history_with_overweight', 'CAEC'])
df_eval_scaled = MinMaxScaler().fit_transform(df_eval)

# Hitung Skor
score = silhouette_score(df_eval_scaled, clusters)
print(f"Silhouette Score (K-Prototypes): {score}")
# Out:
# Silhouette Score (K-Prototypes): 0.1437709854607381
